# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

repo_dir = os.getcwd() + '/repo'
tft_dir = os.path.join(repo_dir, 'tft')
os.chdir(tft_dir)

import warnings  
warnings.filterwarnings('ignore')

# %%
# !ls
# Out:
# data_formatters			       README.md
# expt_settings			       repo
# libs				       requirements.txt
# output_folder			       run.sh
# outputs				       script_download_data.py
# outputs_pm2.5			       script_hyperparam_opt.py
# outputs_stock			       script_train_fixed_params.py
# PRSA_data_2010.1.1-2014.12.31 (1).csv  stock.csv
# PRSA_data_2010.1.1-2014.12.31.csv      tft_data.csv
# __pycache__

# %%
output_folder = os.path.join(os.getcwd(), 'outputs_pm2.5')   # Root folder to save experiment outputs
force_download = False 
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
df = pd.read_csv('PRSA_data_2010.1.1-2014.12.31.csv', index_col=0)

# %%
df = df.fillna(0)
df['id'] = 0
date_list = list()
for i in range(len(df)):
    year = df.iloc[i]['year']
    month = df.iloc[i]['month']
    day = df.iloc[i]['day']
    hour = df.iloc[i]['hour']
    date_list.append(datetime(year, month, day, hour))
df.index = date_list
df['loc'] = 'Beijing'
df['date'] = date_list

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43824 entries, 2010-01-01 00:00:00 to 2014-12-31 23:00:00
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43824 non-null  int64
#  1   month   43824 non-null  int64
#  2   day     43824 non-null  int64
#  3   hour    43824 non-null  int64
#  4   pm2.5   43824 non-null  float64
#  5   DEWP    43824 non-null  int64
#  6   TEMP    43824 non-null  float64
#  7   PRES    43824 non-null  float64
#  8   cbwd    43824 non-null  object
#  9   Iws     43824 non-null  float64
#  10  Is      43824 non-null  int64
#  11  Ir      43824 non-null  int64
#  12  id      43824 non-null  int64
#  13  loc     43824 non-null  object
#  14  date    43824 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(8), object(2)
# memory usage: 5.3+ MB

# %%
df.head()
# Out:
#                      year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd  \
# 2010-01-01 00:00:00  2010      1    1     0    0.0   -21 -11.0  1021.0   NW
# 2010-01-01 01:00:00  2010      1    1     1    0.0   -21 -12.0  1020.0   NW
# 2010-01-01 02:00:00  2010      1    1     2    0.0   -21 -11.0  1019.0   NW
# 2010-01-01 03:00:00  2010      1    1     3    0.0   -21 -14.0  1019.0   NW
# 2010-01-01 04:00:00  2010      1    1     4    0.0   -20 -12.0  1018.0   NW
#
#                        Iws  Is  Ir  id      loc                date
# 2010-01-01 00:00:00   1.79   0   0   0  Beijing 2010-01-01 00:00:00
# 2010-01-01 01:00:00   4.92   0   0   0  Beijing 2010-01-01 01:00:00
# 2010-01-01 02:00:00   6.71   0   0   0  Beijing 2010-01-01 02:00:00
# 2010-01-01 03:00:00   9.84   0   0   0  Beijing 2010-01-01 03:00:00
# 2010-01-01 04:00:00  12.97   0   0   0  Beijing 2010-01-01 04:00:00

# %%
from data_formatters.base import GenericDataFormatter, DataTypes, InputTypes

# View avialable inputs and data types.
print("Available data types:")
for option in DataTypes:
    print(option)

print()
print("Avaialbe input types:")
for option in InputTypes:
    print(option)
# Out:
# Available data types:
# DataTypes.REAL_VALUED
# DataTypes.CATEGORICAL
# DataTypes.DATE
#
# Avaialbe input types:
# InputTypes.TARGET
# InputTypes.OBSERVED_INPUT
# InputTypes.KNOWN_INPUT
# InputTypes.STATIC_INPUT
# InputTypes.ID
# InputTypes.TIME

# %%
from libs import utils 
import sklearn.preprocessing
class PMFormatter(GenericDataFormatter):
    _column_definition = [
        ('id', DataTypes.REAL_VALUED, InputTypes.ID),
        ('date', DataTypes.DATE, InputTypes.TIME),
        ('loc', DataTypes.CATEGORICAL, InputTypes.STATIC_INPUT),
        ('year', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('month', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('day', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('hour', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('DEWP', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('TEMP', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('PRES', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('Iws', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('Is', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('Ir', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('pm2.5', DataTypes.REAL_VALUED, InputTypes.TARGET),
        ('cbwd', DataTypes.CATEGORICAL, InputTypes.OBSERVED_INPUT)
    ]
    
    def __init__(self):
        """initializes formatter"""
        
        self.identifiers = None
        self._real_scalers = None
        self._cat_scalers = None
        self._target_scaler = None
        self._num_classes_per_cat_input = None
    
    def split_data(self, data):
        """
        split data frame into training-validation-test data frames
        
        """
        print('Formatting train-valid-test splits.')
        
        train_start = datetime(2010, 1, 1, 0)
        train_end = datetime(2012, 12, 31, 23)
        train_data = data.loc[train_start:train_end]

        val_start = datetime(2013, 1, 1, 0)
        val_end = datetime(2013, 12, 31, 23)
        val_data = data.loc[val_start:val_end]

        test_start = datetime(2014, 1, 1, 0)
        test_end = datetime(2014, 12, 31 ,23)
        test_data = data.loc[test_start:test_end]
        
        self.set_scalers(train_data)
        
        return (self.transform_inputs(data) for data in [train_data, val_data, test_data])
    
    def set_scalers(self, df):
        """
        Calibrates scalers using the data supplied.
        (제공된 데이터를 사용해서 scaler 교정)

        Args:
          df: Data to use to calibrate scalers.
        """
        print('Setting scalers with training data...')
        
        column_definitions = self.get_column_definition()

        id_column = utils.get_single_col_by_input_type(InputTypes.ID,
                                                       column_definitions)
        target_column = utils.get_single_col_by_input_type(InputTypes.TARGET,
                                                           column_definitions)
        # extract identifiers in case required
#         stock에는 identifier가 현재 따로 필요해보이지 않음(데이터 entity가 한개이기 때문)
#         self.identifiers = list(df[id_column].unique())
        
        # Format real scalers
        real_inputs = utils.extract_cols_from_data_type(
            DataTypes.REAL_VALUED, column_definitions,
            {InputTypes.ID, InputTypes.TIME})
        
        data = df[real_inputs].values
        self._real_scalers = sklearn.preprocessing.StandardScaler().fit(data)
        
        # target데이터를 prediction에 사용
        self._target_scaler = sklearn.preprocessing.StandardScaler().fit(df[[target_column]].values)
        
        categorical_inputs = utils.extract_cols_from_data_type(
            DataTypes.CATEGORICAL, column_definitions,
            {InputTypes.ID, InputTypes.TIME})
        
        categorical_scalers = {}
        num_classes = []
        for col in categorical_inputs:
            srs = df[col].apply(str)
            categorical_scalers[col] = sklearn.preprocessing.LabelEncoder().fit(srs.values)
            num_classes.append(srs.nunique())
        
        # set categorical scaler outputs
        self._cat_scalers = categorical_scalers
        self._num_classes_per_cat_input = num_classes
        
    def transform_inputs(self, df):
        """
        performs feature transformations.
        
        feature engineering, preprocessing and normalization을 포함
        
        Args:
            df - data frame to transform.
            
        Returns:
            Transformed data frame.
        """
        output = df.copy()
        
        if self._real_scalers is None and self._cat_scalers is None:
            raise ValueError('Scalers have not been set!')
        
        column_definitions = self.get_column_definition()
        real_inputs = utils.extract_cols_from_data_type(
            DataTypes.REAL_VALUED, column_definitions,
            {InputTypes.ID, InputTypes.TIME}
        )
        categorical_inputs = utils.extract_cols_from_data_type(
            DataTypes.CATEGORICAL, column_definitions,
            {InputTypes.ID, InputTypes.TIME})
        output[real_inputs] = self._real_scalers.transform(df[real_inputs].values)
        for col in categorical_inputs:
            string_df = df[col].apply(str)
            output[col] = self._cat_scalers[col].transform(string_df)
        return output
    
    def format_predictions(self, predictions):
        output = predictions.copy()
        
        column_names = predictions.columns
        for col in column_names:
            if col not in {'forecast_time', 'identifier'}:
                output[col] = self._target_scaler.inverse_transform(predictions[col])
                
        return output
    
    def get_fixed_params(self):
        fixed_params = {
            'total_time_steps': 36,     # Total width of the Temporal Fusion Decoder
            'num_encoder_steps': 24,    # Length of LSTM decoder (ie. # historical inputs)
            'num_epochs': 100,            # Max number of epochs for training
            'early_stopping_patience': 5, # Early stopping threshold for # iterations with no loss improvement
            'multiprocessing_workers': 5  # Number of multi-processing workers
        }
        
        return fixed_params
    
    def get_default_model_params(self):
        model_params = {
            'dropout_rate': 0.3,
            'hidden_layer_size': 160,
            'learning_rate': 0.01,
            'minibatch_size': 64,
            'max_gradient_norm': 0.01,
            'num_heads': 1,
            'stack_size': 1
        }

        return model_params

# %%
data_formatter = PMFormatter()
train, valid, test = data_formatter.split_data(df)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration(
  )
# Out:
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
test
# Out:
#                          year     month       day      hour     pm2.5  \
# 2014-01-01 00:00:00  3.672282 -1.601021 -1.673906 -1.661325 -0.745513
# 2014-01-01 01:00:00  3.672282 -1.601021 -1.673906 -1.516862 -0.421908
# 2014-01-01 02:00:00  3.672282 -1.601021 -1.673906 -1.372399 -0.288003
# 2014-01-01 03:00:00  3.672282 -1.601021 -1.673906 -1.227936 -0.232209
# 2014-01-01 04:00:00  3.672282 -1.601021 -1.673906 -1.083473 -0.131780
# 2014-01-01 05:00:00  3.672282 -1.601021 -1.673906 -0.939010  0.013285
# 2014-01-01 06:00:00  3.672282 -1.601021 -1.673906 -0.794547  0.169508
# 2014-01-01 07:00:00  3.672282 -1.601021 -1.673906 -0.650084 -0.176415
# 2014-01-01 08:00:00  3.672282 -1.601021 -1.673906 -0.505621 -0.366114
# 2014-01-01 09:00:00  3.672282 -1.601021 -1.673906 -0.361158 -0.645084
# 2014-01-01 10:00:00  3.672282 -1.601021 -1.673906 -0.216695 -0.444225
# 2014-01-01 11:00:00  3.672282 -1.601021 -1.673906 -0.072232 -0.656242
# 2014-01-01 12:00:00  3.672282 -1.601021 -1.673906  0.072232 -0.756671
# 2014-01-01 13:00:00  3.672282 -1.601021 -1.673906  0.216695 -0.700877
# 2014-01-01 14:00:00  3.672282 -1.601021 -1.673906  0.361158 -0.756671
# 2014-01-01 15:00:00  3.672282 -1.601021 -1.673906  0.505621 -0.745513
# 2014-01-01 16:00:00  3.672282 -1.601021 -1.673906  0.650084 -0.723195
# 2014-01-01 17:00:00  3.672282 -1.601021 -1.673906  0.794547 -0.723195
# 2014-01-01 18:00:00  3.672282 -1.601021 -1.673906  0.939010 -0.712036
# 2014-12-31 09:00:00 -0.142394   0    0 2014-12-31 09:00:00
# 2014-12-31 10:00:00 -0.142394   0    0 2014-12-31 10:00:00
# 2014-12-31 11:00:00 -0.142394   0    0 2014-12-31 11:00:00
# 2014-12-31 12:00:00 -0.142394   0    0 2014-12-31 12:00:00
# 2014-12-31 13:00:00 -0.142394   0    0 2014-12-31 13:00:00
# 2014-12-31 14:00:00 -0.142394   0    0 2014-12-31 14:00:00
# 2014-12-31 15:00:00 -0.142394   0    0 2014-12-31 15:00:00
# 2014-12-31 16:00:00 -0.142394   0    0 2014-12-31 16:00:00
# 2014-12-31 17:00:00 -0.142394   0    0 2014-12-31 17:00:00
# 2014-12-31 18:00:00 -0.142394   0    0 2014-12-31 18:00:00
# 2014-12-31 19:00:00 -0.142394   0    0 2014-12-31 19:00:00
# 2014-12-31 20:00:00 -0.142394   0    0 2014-12-31 20:00:00
# 2014-12-31 21:00:00 -0.142394   0    0 2014-12-31 21:00:00
# 2014-12-31 22:00:00 -0.142394   0    0 2014-12-31 22:00:00
# 2014-12-31 23:00:00 -0.142394   0    0 2014-12-31 23:00:00
#
# [8760 rows x 15 columns]

# %%
import libs.hyperparam_opt
import libs.tft_model
import libs.utils as util

ModelClass = libs.tft_model.TemporalFusionTransformer
data_params = data_formatter.get_experiment_params()
param_ranges = ModelClass.get_hyperparm_choices()

# %%
model_params = {'dropout_rate': 0.3,      # Dropout discard rate
                'hidden_layer_size': 320, # Internal state size of TFT
                'learning_rate': 0.001,   # ADAM initial learning rate
                'minibatch_size': 128,    # Minibatch size for training
                'max_gradient_norm': 100.,# Max norm for gradient clipping
                'num_heads': 1,           # Number of heads for multi-head attention
                'stack_size': 1           # Number of stacks (default 1 for interpretability)
               }

# %%
model_folder = os.path.join(output_folder, 'saved_models', 'pm2.5(v2)', 'fixed')
model_params['model_folder'] = model_folder

model_params.update(data_params)

# %%
HyperparamOptManager = libs.hyperparam_opt.HyperparamOptManager
print("*** Loading hyperparm manager ***")
opt_manager = HyperparamOptManager(param_ranges, data_params, model_folder)
# Out:
# *** Loading hyperparm manager ***

# %%
success = opt_manager.load_results()
restart_opt = 'yes'
if success and not restart_opt:
    print("Loaded results from previous training")
else:
    print("Creating new hyperparameter optimisation")
    opt_manager.clear()
# Out:
# Loading results from /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed
# Creating new hyperparameter optimisation

# %%
import tensorflow as tf
from libs.tft_model import TemporalFusionTransformer

# Specify GPU usage
tf_config = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=2)
# Out:
# Selecting GPU ID=2

# %%
tf.compat.v1.get_default_graph()
with tf.Graph().as_default(), tf.compat.v1.Session(config=tf_config) as sess:

    tf.compat.v1.keras.backend.set_session(sess)
    params = opt_manager.get_next_parameters()
    # Create a TFT model
    model = TemporalFusionTransformer(model_params,
                                    use_cudnn=True) # Run model on GPU using CuDNNLSTM cells

    # Sample data into minibatches for training
    if not model.training_data_cached():
        model.cache_batched_data(train, "train", num_samples=train_samples)
        model.cache_batched_data(valid, "valid", num_samples=valid_samples)

    # Train and save model
    model.fit()
    
    val_loss = model.evaluate()
    if np.allclose(val_loss, 0.) or np.isnan(val_loss):
        # Set all invalid losses to infintiy.
        # N.b. val_loss only becomes 0. when the weights are nan.
        print("Skipping bad configuration....")
        val_loss = np.inf
    opt_manager.update_score(params, val_loss, model)
    tf.compat.v1.keras.backend.set_session(sess)
    model.save(model_folder)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0e:00.0, compute capability: 7.0
#
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 320
# # learning_rate = 0.001
# # minibatch_size = 128
# # max_gradient_norm = 100.0
# # num_heads = 1
# # stack_size = 1
# # model_folder = /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed
# # total_time_steps = 36
# # num_encoder_steps = 24
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('date', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('year', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('month', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hour', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('DEWP', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('TEMP', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('PRES', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Iws', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Is', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Ir', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('pm2.5', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('loc', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>), ('cbwd', <DataTypes.CATEGORICAL: 1>, <InputTypes.OBSERVED_INPUT: 1>)]
# # input_size = 13
# # output_size = 1
# # category_counts = [1, 4]
# # input_obs_loc = [10]
# # static_input_loc = [11]
# # known_regular_inputs = [0, 1, 2, 3]
# # known_categorical_inputs = [0]
# Tensor("TemporalFusionTransformer/stack:0", shape=(None, 1, 320), dtype=float32)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 36, 13)]     0
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 2)]      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36)]         0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 36, 320)      320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           sequential[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 320)          102720      flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation (Activation)         (None, 320)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 320)       102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 320)          102720      activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 320)       0           dense_16[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 320)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 320)       102720      activation_2[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 320)       0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            321         flatten[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1)            0           dense_14[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_11[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 320)       0           dense_18[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1)            2           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1, 320)       640         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 1)]       0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 320)          0           dense_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 11)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 320)          102720      activation_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36)]         0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 320)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 36, 320)      1280        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 7)] 0           time_distributed_1[0][0]
#                                                                  time_distributed_2[0][0]
#                                                                  time_distributed_3[0][0]
#                                                                  time_distributed_4[0][0]
#                                                                  time_distributed_5[0][0]
#                                                                  time_distributed_6[0][0]
#                                                                  sequential_1[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 4)] 0           time_distributed_7[0][0]
#                                                                  time_distributed_8[0][0]
#                                                                  time_distributed_9[0][0]
#                                                                  time_distributed_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 1)] 0           time_distributed[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 320)          0           dense_22[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 7)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 4)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 1)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 12) 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 320)          640         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 3840)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320, 4)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 24, 320)      1229120     tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 1280)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           time_distributed_12[0][0]
#                                                                  time_distributed_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 12, 320)      409920      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           time_distributed_66[0][0]
#                                                                  time_distributed_67[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 24, 320)      102720      activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 320)      0           time_distributed_17[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 24, 320)      0           time_distributed_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 320)      0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 24, 320)      0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 320)      0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 320)      0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 320)      0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 320)      0           time_distributed_45[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 320)      0           time_distributed_49[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 24, 320)      0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 320)      0           time_distributed_57[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 24, 320)      0           time_distributed_61[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 12, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 320)      0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 24, 320)      102720      activation_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 24, 320)      102720      activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 24, 320)      102720      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 24, 320)      102720      activation_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 24, 320)      102720      activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 24, 320)      102720      activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 24, 320)      102720      activation_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 24, 320)      102720      activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 24, 320)      102720      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 24, 320)      102720      activation_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 24, 320)      102720      activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 24, 320)      102720      activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 12, 320)      102720      activation_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 320)      0           time_distributed_71[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 320)      0           time_distributed_75[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 320)      0           time_distributed_79[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 320)      0           time_distributed_83[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 24, 12)       3852        dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 24, 12)       3852        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 24, 320)      0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 24, 320)      0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 24, 320)      0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 24, 320)      0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 24, 320)      0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 24, 320)      0           time_distributed_38[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 24, 320)      0           time_distributed_42[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 24, 320)      0           time_distributed_46[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 24, 320)      0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 24, 320)      0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 24, 320)      0           time_distributed_58[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 24, 320)      0           time_distributed_62[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 12, 320)      0           time_distributed_68[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 12, 320)      102720      activation_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 12, 320)      102720      activation_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (None, 12, 320)      102720      activation_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (None, 12, 320)      102720      activation_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 24, 12)       46092       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 24, 12)       0           time_distributed_15[0][0]
#                                                                  time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 24, 320)      102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 24, 320)      102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 24, 320)      102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 24, 320)      102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 24, 320)      102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 24, 320)      102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 24, 320)      102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 24, 320)      102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 24, 320)      102720      dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 24, 320)      102720      dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 24, 320)      102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 24, 320)      102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 24, 320)      102720      dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 24, 320)      102720      dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 24, 320)      102720      dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 24, 320)      102720      dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 24, 320)      102720      dropout_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 24, 320)      102720      dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 320)          0           dense_28[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 320)          0           dense_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 12, 4)        1284        dropout_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 12, 4)        1284        dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 12, 320)      0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 12, 320)      0           time_distributed_76[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 12, 320)      0           time_distributed_80[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 12, 320)      0           time_distributed_84[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 24, 12)       0           time_distributed_11[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 24, 320)      0           time_distributed_19[0][0]
#                                                                  time_distributed_20[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 24, 320)      0           time_distributed_23[0][0]
#                                                                  time_distributed_24[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 24, 320)      0           time_distributed_27[0][0]
#                                                                  time_distributed_28[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 24, 320)      0           time_distributed_31[0][0]
#                                                                  time_distributed_32[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 24, 320)      0           time_distributed_35[0][0]
#                                                                  time_distributed_36[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 24, 320)      0           time_distributed_39[0][0]
#                                                                  time_distributed_40[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 24, 320)      0           time_distributed_43[0][0]
#                                                                  time_distributed_44[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 24, 320)      0           time_distributed_47[0][0]
#                                                                  time_distributed_48[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 24, 320)      0           time_distributed_51[0][0]
# ...
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 36, 320)      0           multiply_27[0][0]
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 320)          640         add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 36, 320)      640         add_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_89 (TimeDistri (None, 36, 320)      102720      layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_90 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320)]    0           time_distributed_89[0][0]
#                                                                  time_distributed_90[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 36, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_91 (TimeDistri (None, 36, 320)      102720      activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 36, 320)      0           time_distributed_91[0][0]
# __________________________________________________________________________________________________
# time_distributed_92 (TimeDistri (None, 36, 320)      102720      dropout_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_93 (TimeDistri (None, 36, 320)      102720      dropout_25[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 36, 320)      0           time_distributed_92[0][0]
#                                                                  time_distributed_93[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 36, 320)      0           layer_normalization_24[0][0]
#                                                                  multiply_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 36, 320)      640         add_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(3,)]               0           layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [()]                 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(3,)]               0           layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [()]                 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(2,)]               0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None)]       0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_120 (Dense)               (None, 36, 320)      102400      layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_121 (Dense)               (None, 36, 320)      102400      layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 36, 36)       0           dense_120[0][0]
#                                                                  dense_121[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 36, 36)       0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 36, 36)       0           add_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 36, 36)       0           activation_28[0][0]
# __________________________________________________________________________________________________
# dense_119 (Dense)               (None, 36, 320)      102400      layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 36, 320)      0           dropout_26[0][0]
#                                                                  dense_119[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 36, 320)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_122 (Dense)               (None, 36, 320)      102400      dropout_27[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 36, 320)      0           dense_122[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 36, 320)      0           dropout_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_94 (TimeDistri (None, 36, 320)      102720      dropout_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_95 (TimeDistri (None, 36, 320)      102720      dropout_29[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 36, 320)      0           time_distributed_94[0][0]
#                                                                  time_distributed_95[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 36, 320)      0           multiply_29[0][0]
#                                                                  layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 36, 320)      640         add_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_96 (TimeDistri (None, 36, 320)      102720      layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 36, 320)      0           time_distributed_96[0][0]
# __________________________________________________________________________________________________
# time_distributed_97 (TimeDistri (None, 36, 320)      102720      activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 36, 320)      0           time_distributed_97[0][0]
# __________________________________________________________________________________________________
# time_distributed_98 (TimeDistri (None, 36, 320)      102720      dropout_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_99 (TimeDistri (None, 36, 320)      102720      dropout_30[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 36, 320)      0           time_distributed_98[0][0]
#                                                                  time_distributed_99[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 36, 320)      0           layer_normalization_26[0][0]
#                                                                  multiply_30[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 36, 320)      640         add_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_100 (TimeDistr (None, 36, 320)      102720      layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_101 (TimeDistr (None, 36, 320)      102720      layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 36, 320)      0           time_distributed_100[0][0]
#                                                                  time_distributed_101[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 36, 320)      0           multiply_31[0][0]
#                                                                  layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 36, 320)      640         add_29[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_102 (TimeDistr (None, 12, 3)        963         tf_op_layer_TemporalFusionTransfo
# ==================================================================================================
# Total params: 14,562,968
# Trainable params: 14,562,968
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Cached data "train" updated
# Cached data "valid" updated
# *** Fitting TemporalFusionTransformer ***
# Getting batched_data
# Using cached training data
# Using cached validation data
# Using keras standard fit
# Train on 26269 samples, validate on 8725 samples
# Epoch 1/100
# 26269/26269 [==============================] - ETA: 0s - loss: 0.5286WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 26269/26269 [==============================] - 35s 1ms/sample - loss: 0.5286 - val_loss: 0.4444
# Epoch 2/100
# 26269/26269 [==============================] - 31s 1ms/sample - loss: 0.3891 - val_loss: 0.4230
# Epoch 3/100
# 26269/26269 [==============================] - 31s 1ms/sample - loss: 0.3710 - val_loss: 0.4230
# Epoch 4/100
# 26269/26269 [==============================] - 31s 1ms/sample - loss: 0.3583 - val_loss: 0.4192
# Epoch 5/100
# 26269/26269 [==============================] - 31s 1ms/sample - loss: 0.3447 - val_loss: 0.4145
# Epoch 6/100
# 26269/26269 [==============================] - 30s 1ms/sample - loss: 0.3298 - val_loss: 0.4270
# Epoch 7/100
# 26269/26269 [==============================] - 30s 1ms/sample - loss: 0.3039 - val_loss: 0.4317
# Epoch 8/100
# 26269/26269 [==============================] - 30s 1ms/sample - loss: 0.2816 - val_loss: 0.4821
# Epoch 9/100
# 26269/26269 [==============================] - 30s 1ms/sample - loss: 0.2472 - val_loss: 0.4985
# Epoch 10/100
# 26269/26269 [==============================] - 30s 1ms/sample - loss: 0.2184 - val_loss: 0.5219
# Cannot load from /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed/tmp, skipping ...
# Using cached validation data
# Optimal model found, updating
# Model saved to: /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed/TemporalFusionTransformer.ckpt
# Model saved to: /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed/TemporalFusionTransformer.ckpt

# %%
tf.compat.v1.reset_default_graph()
with tf.Graph().as_default(), tf.compat.v1.Session(config=tf_config) as sess:
    tf.compat.v1.keras.backend.set_session(sess)
    # Create a new model & load weights
    model = TemporalFusionTransformer(model_params,
                                      use_cudnn=True)
    model.load(model_folder)
    
    # Make forecasts
    output_map = model.predict(test, return_targets=True)
    
    targets = data_formatter.format_predictions(output_map["targets"])
    # Format predictions
    
    p50_forecast = data_formatter.format_predictions(output_map["p50"])
    p90_forecast = data_formatter.format_predictions(output_map["p90"])

    def extract_numerical_data(data):
        """Strips out forecast time and identifier columns."""
        return data[[
            col for col in data.columns
            if col not in {"forecast_time", "identifier"}
        ]]
    # Compute Losses
    p50_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p50_forecast),
        0.5)
    p90_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p90_forecast),
        0.9)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0e:00.0, compute capability: 7.0
#
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 320
# # learning_rate = 0.001
# # minibatch_size = 128
# # max_gradient_norm = 100.0
# # num_heads = 1
# # stack_size = 1
# # model_folder = /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed
# # total_time_steps = 36
# # num_encoder_steps = 24
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('date', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('year', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('month', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hour', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('DEWP', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('TEMP', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('PRES', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Iws', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Is', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Ir', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('pm2.5', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('loc', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>), ('cbwd', <DataTypes.CATEGORICAL: 1>, <InputTypes.OBSERVED_INPUT: 1>)]
# # input_size = 13
# # output_size = 1
# # category_counts = [1, 4]
# # input_obs_loc = [10]
# # static_input_loc = [11]
# # known_regular_inputs = [0, 1, 2, 3]
# # known_categorical_inputs = [0]
# Tensor("TemporalFusionTransformer/stack:0", shape=(None, 1, 320), dtype=float32)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 36, 13)]     0
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 2)]      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36)]         0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 36, 320)      320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           sequential[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 320)          0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 320)          102720      flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation (Activation)         (None, 320)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 320)       102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 320)          102720      activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 320)       0           dense_16[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 320)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 320)       102720      activation_2[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            321         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 320)       0           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            321         flatten[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1)            0           dense_14[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 320)       102720      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_11[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 320)       0           dense_18[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1)            2           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1, 320)       640         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 1)]       0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 320)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 320)]        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 320)          0           dense_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 11)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 320)          102720      activation_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36)]         0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 1)]      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 320)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 36, 320)      1280        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 36, 320)      640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 320)          102720      dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 7)] 0           time_distributed_1[0][0]
#                                                                  time_distributed_2[0][0]
#                                                                  time_distributed_3[0][0]
#                                                                  time_distributed_4[0][0]
#                                                                  time_distributed_5[0][0]
#                                                                  time_distributed_6[0][0]
#                                                                  sequential_1[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 4)] 0           time_distributed_7[0][0]
#                                                                  time_distributed_8[0][0]
#                                                                  time_distributed_9[0][0]
#                                                                  time_distributed_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 36, 320, 1)] 0           time_distributed[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 320)          0           dense_22[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 7)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 4)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 1)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 320)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320, 12) 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 320)          640         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 3840)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320, 4)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 24, 320)      1229120     tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 1280)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 320)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           time_distributed_12[0][0]
#                                                                  time_distributed_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 12, 320)      409920      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 1, 320)       102400      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 24, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           time_distributed_66[0][0]
#                                                                  time_distributed_67[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 12, 320)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 24, 320)      102720      activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 320)      0           time_distributed_17[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 24, 320)      0           time_distributed_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 320)      0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 24, 320)      0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 320)      0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 320)      0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 320)      0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 320)      0           time_distributed_45[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 320)      0           time_distributed_49[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 24, 320)      0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 320)      0           time_distributed_57[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 24, 320)      0           time_distributed_61[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 12, 320)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (None, 12, 320)      102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 320)      0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 24, 320)      102720      activation_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 24, 320)      102720      activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 24, 320)      102720      activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 24, 320)      102720      activation_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 24, 320)      102720      activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 24, 320)      102720      activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 24, 320)      102720      activation_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 24, 320)      102720      activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 24, 320)      102720      activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 24, 320)      102720      activation_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 24, 320)      102720      activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 24, 320)      102720      activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 12, 320)      102720      activation_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 320)      0           time_distributed_71[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 320)      0           time_distributed_75[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 320)      0           time_distributed_79[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 320)      0           time_distributed_83[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 24, 12)       3852        dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 24, 12)       3852        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 24, 320)      0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 24, 320)      0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 24, 320)      0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 24, 320)      0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 24, 320)      0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 24, 320)      0           time_distributed_38[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 24, 320)      0           time_distributed_42[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 24, 320)      0           time_distributed_46[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 24, 320)      0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 24, 320)      0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 24, 320)      0           time_distributed_58[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 24, 320)      0           time_distributed_62[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 320)          102720      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 12, 320)      0           time_distributed_68[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 12, 320)      102720      activation_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 12, 320)      102720      activation_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (None, 12, 320)      102720      activation_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (None, 12, 320)      102720      activation_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 24, 12)       46092       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 24, 12)       0           time_distributed_15[0][0]
#                                                                  time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 24, 320)      102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 24, 320)      102720      dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 24, 320)      102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 24, 320)      102720      dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 24, 320)      102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 24, 320)      102720      dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 24, 320)      102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 24, 320)      102720      dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 24, 320)      102720      dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 24, 320)      102720      dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 24, 320)      102720      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 24, 320)      102720      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 24, 320)      102720      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 24, 320)      102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 24, 320)      102720      dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 24, 320)      102720      dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 24, 320)      102720      dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 24, 320)      102720      dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 24, 320)      102720      dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 24, 320)      102720      dropout_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 24, 320)      102720      dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 320)          0           dense_28[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 320)          0           dense_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 12, 4)        1284        dropout_19[0][0]
# __________________________________________________________________________________________________
# time_distributed
#   9.28863790e-03  1.43330696e-03 -2.10831131e-04 -8.71319417e-03
#  -6.34321803e-03 -3.17429402e-03 -9.77651961e-03 -3.95657215e-03
#   6.88161876e-04  6.28279988e-04 -6.88823080e-03 -4.91336361e-03
#   1.24915512e-02 -6.76490192e-04 -8.09442904e-03 -4.19046544e-03
#  -1.35705434e-02  1.16384430e-02 -6.15647528e-03 -5.57943154e-03
#  -8.66373628e-03  3.69399233e-04 -9.52521432e-03 -2.08093622e-03
#  -6.88746432e-03 -4.99679474e-03 -1.38067594e-03 -1.40409442e-02
#   2.36890209e-03 -1.14328100e-03 -4.03759163e-03 -1.08030522e-02
#  -9.33685689e-04 -2.03854521e-03  2.48157536e-03  5.95091330e-03
#   9.86257568e-03  5.10833983e-04 -4.69053164e-04 -4.54270933e-03]
# tensor: TemporalFusionTransformer/time_distributed_99/kernel (float32) [320, 320]
# [[ 0.08239958  0.00068864 -0.05501417 ...  0.07198587 -0.01184325
#    0.00487405]
#  [-0.03156367 -0.06534661  0.05415102 ...  0.02139101 -0.09118358
#   -0.08202621]
#  [ 0.1011783  -0.03202287  0.07676957 ...  0.07091384 -0.00504476
#    0.04557193]
#  ...
#  [-0.01853643 -0.02711928  0.07026376 ...  0.02342146 -0.00504444
#   -0.06648463]
#  [ 0.07814372  0.08626596 -0.00128764 ... -0.04142068 -0.03859379
#    0.08977617]
#  [ 0.08593725 -0.09563437  0.06794714 ...  0.0987433  -0.07159505
#    0.03690014]]
# # Total number of params: 14562968
# INFO:tensorflow:Restoring parameters from /workspace/inkyung/TFT/repo/tft/outputs_pm2.5/saved_models/pm2.5(v2)/fixed/TemporalFusionTransformer.ckpt
# Done.

# %%
import datetime as dte
print("Hyperparam optimisation completed @ {}".format(dte.datetime.now()))
print("Best validation loss = {}".format(val_loss))
# print("Params:")

# for k in best_params:
#     print(k, " = ", best_params[k])
#     print()
print("Normalised quantile losses: P50={}, P90={}".format(p50_loss.mean(), p90_loss.mean()))
# Out:
# Hyperparam optimisation completed @ 2021-07-04 07:51:44.179721
# Best validation loss = 0.521871545810071
# Normalised quantile losses: P50=0.40483039682602745, P90=0.25946559317297174

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 3))
plt.plot(output_map['targets']['t+0'][200:400], label='target')
plt.plot(output_map['p10']['t+0'][200:400], label='p10')
plt.plot(output_map['p50']['t+0'][200:400], label='p50')
plt.plot(output_map['p90']['t+0'][200:400], label='p90')
plt.legend(loc='upper left', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 3))
plt.plot(output_map['targets']['t+0'][200:400], label='target')
# plt.plot(output_map['p10']['t+0'][200:400], label='p10')
plt.plot(output_map['p50']['t+0'][200:400], label='p50')
# plt.plot(output_map['p90']['t+0'][200:400], label='p90')
plt.legend(loc='upper left', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(output_map['targets']['t+0'][100:200], label='target')
plt.plot(output_map['p10']['t+0'][100:200], label='p10')
plt.plot(output_map['p50']['t+0'][100:200], label='p50')
plt.plot(output_map['p90']['t+0'][100:200], label='p90')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(output_map['targets']['t+0'][200:300], label='target')
plt.plot(output_map['p10']['t+0'][200:300], label='p10')
plt.plot(output_map['p50']['t+0'][200:300], label='p50')
plt.plot(output_map['p90']['t+0'][200:300], label='p90')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
